# %%
import h5py 
import numpy as np
import matplotlib.pyplot as plt
import os

import sys
sys.path.append("..")
from data.utils import distinct_colors
from models.datasets import PartNetDataset, TreePartNetDataset
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
with h5py.File("/space/ariyanzarei/sorghum_segmentation/dataset/TreePartNetData/tree_labeled_train.hdf5") as f:
    print(f.keys())
    points = np.array(f['points'])
    labels = np.array(f['lc'])
    affinity_matrices = np.array(f['codebook'])
    samples = np.array(f['samples'])
    print(points.dtype)
    print(labels.dtype)
    print(affinity_matrices.dtype)
    print(samples.dtype)
# Out:
# <KeysViewHDF5 ['codebook', 'isforks', 'lc', 'names', 'normals', 'points', 'primitive_id', 'samples']>
# float64
# int64
# float64
# int32

# %%
dataset = TreePartNetDataset("/space/ariyanzarei/sorghum_segmentation/dataset/TreePartNetData/", "test")
points, labels = dataset[0:10]
points = points.numpy()
labels = labels.numpy()
print(points.shape)
print(labels.shape)
# Out:
# (10, 8000, 3)
# (10, 8000)

# %%
ind = 3
p = points[ind]
label = labels[ind]
matrix = affinity_matrices[ind]

print(matrix.sum())

rotation_matrix = np.eye(4)
rotation_matrix[1,1] = 0
rotation_matrix[1,2] = 1
rotation_matrix[2,1] = -1
rotation_matrix[2,2] = 0

new_p = np.matmul(np.hstack((p, np.ones((p.shape[0],1)))), rotation_matrix)
p = new_p

d_colors = distinct_colors(len(list(set(label))))
colors = np.zeros((label.shape[0],3))
for i, l in enumerate(list(set(label))):
    colors[label == l, :] = d_colors[i]
    
fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(projection='3d')
ax.scatter(p[:,0],p[:,1],p[:,2], s=3, c=colors)
ax.set_xlabel("x: index 0")
ax.set_ylabel("y: index 1")
ax.set_zlabel("z: index 2")
plt.show()
# Out:
# 848.0
